# %% [markdown]
# **05-Visualizations**
# Using outputs saved from 03 and 04, create visualizations that reveal patterns from the data.

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import PowerNorm

# %%
REPO_ROOT = Path("~/scRNA-cross-donor-generalization").expanduser()   # change if needed
os.chdir(REPO_ROOT)

# %%
# -------------------------
# paths
# -------------------------
tables_dir = Path("results/tables")
figures_dir = Path("results/figures")
figures_dir.mkdir(parents=True, exist_ok=True)

schemeA_path = tables_dir / "schemeA_summary.csv"
schemeB_path = tables_dir / "schemeB_summary.csv"

# -------------------------
# read csvs
# -------------------------
schemeA = pd.read_csv(schemeA_path)
schemeB = pd.read_csv(schemeB_path)

print("Scheme A columns:", schemeA.columns.tolist())
print("Scheme B columns:", schemeB.columns.tolist())

display(schemeA)
display(schemeB)

# -------------------------
# common settings
# -------------------------
rep_order = ["hvg", "pca", "harmony", "scvi"]
rep_labels = ["HVG", "PCA", "Harmony", "scVI"]

cross_site_path = tables_dir / "cross_site_summary.csv"
cross_site_df = pd.read_csv(cross_site_path)

cross_site_df["direction"] = cross_site_df["direction"].str.replace("Ncl", "Newcastle")

cross_site_df["representation"] = pd.Categorical(
    cross_site_df["representation_clean"],
    categories=rep_order,
    ordered=True
)

# =========================================================
# Figure 2A: Scheme A, filtered vs full, no batch covariate
# =========================================================
fig2A_df = schemeA[schemeA["batch"] == "no"].copy()

fig2A_df["representation_clean"] = fig2A_df["representation"].replace({
    "hvg": "hvg",
    "X_pca": "pca",
    "X_harmony": "harmony",
    "X_scVI": "scvi",
})

filtered_df = (
    fig2A_df[fig2A_df["dataset"] == "filtered"]
    .set_index("representation_clean")
    .reindex(rep_order)
)

full_df = (
    fig2A_df[fig2A_df["dataset"] == "full"]
    .set_index("representation_clean")
    .reindex(rep_order)
)

# =========================================================
# Figure 2B: filtered dataset, no batch covariate
# Scheme A random split vs Scheme B donor-held-out
# =========================================================
fig2B_A = schemeA[
    (schemeA["dataset"] == "filtered") &
    (schemeA["batch"] == "no")
].copy()

fig2B_B = schemeB[
    (schemeB["dataset"] == "filtered") &
    (schemeB["batch"] == "no")
].copy()

fig2B_A = fig2B_A[["representation", "macro_f1", "accuracy"]].copy()
fig2B_A["representation"] = fig2B_A["representation"].replace({
    "hvg": "hvg",
    "X_pca": "pca",
    "X_harmony": "harmony",
    "X_scVI": "scvi",
})
fig2B_A["macro_f1_std"] = 0.0
fig2B_A["scheme_label"] = "Random split"

fig2B_B = fig2B_B[["representation", "macro_f1_mean", "macro_f1_std", "accuracy_mean"]].copy()
fig2B_B["representation"] = fig2B_B["representation"].replace({
    "hvg": "hvg",
    "X_pca": "pca",
    "X_harmony": "harmony",
    "X_scVI": "scvi",
})
fig2B_B = fig2B_B.rename(columns={
    "macro_f1_mean": "macro_f1",
    "accuracy_mean": "accuracy"
})
fig2B_B["scheme_label"] = "Donor-held-out"

plot_df = pd.concat([fig2B_A, fig2B_B], ignore_index=True)
plot_df["representation"] = pd.Categorical(
    plot_df["representation"],
    categories=rep_order,
    ordered=True
)
plot_df = plot_df.sort_values(["representation", "scheme_label"]).reset_index(drop=True)

random_df = (
    plot_df[plot_df["scheme_label"] == "Random split"]
    .set_index("representation")
    .loc[rep_order]
)

donor_df = (
    plot_df[plot_df["scheme_label"] == "Donor-held-out"]
    .set_index("representation")
    .loc[rep_order]
)

print("Figure 2B plotting dataframe:")
display(plot_df)

# -------------------------
# prepare data for Figure 2C: cross-site generalization
# -------------------------
fig2C_df = cross_site_df.copy()

# pivot so each direction is a column
fig2C_pivot = fig2C_df.pivot(
    index="representation",
    columns="direction",
    values="macro_f1"
).loc[rep_order]

directions = fig2C_pivot.columns.tolist()

# -------------------------
# combined plot
# -------------------------
x = np.arange(len(rep_order))
width = 0.36

fig, axes = plt.subplots(1, 3, figsize=(20, 5.8))

# -------- Panel A --------
bars_filtered = axes[0].bar(
    x - width/2,
    filtered_df["macro_f1"],
    width,
    label="Filtered dataset",
    edgecolor="black"
)

bars_full = axes[0].bar(
    x + width/2,
    full_df["macro_f1"],
    width,
    label="Full dataset",
    edgecolor="black"
)

axes[0].set_xticks(x)
axes[0].set_xticklabels(rep_labels)
axes[0].set_xlabel("Representation")
axes[0].set_ylabel("Macro F1")
axes[0].set_title("A. Effect of cell type filtering under random split")
axes[0].legend(frameon=False)

ymin_A = min(filtered_df["macro_f1"].min(), full_df["macro_f1"].min())
ymax_A = max(filtered_df["macro_f1"].max(), full_df["macro_f1"].max())
axes[0].set_ylim(ymin_A - 0.01, ymax_A + 0.02)

for bars in [bars_filtered, bars_full]:
    for bar in bars:
        h = bar.get_height()
        axes[0].text(
            bar.get_x() + bar.get_width() / 2,
            h + 0.003,
            f"{h:.3f}",
            ha="center",
            va="bottom",
            fontsize=9
        )

# -------- Panel B --------
bars_random = axes[1].bar(
    x - width/2,
    random_df["macro_f1"],
    width,
    label="Random (cell-level split)",
    edgecolor="black"
)

bars_donor = axes[1].bar(
    x + width/2,
    donor_df["macro_f1"],
    width,
    yerr=donor_df["macro_f1_std"],
    capsize=5,
    label="Donor-held-out (cross-donor)",
    edgecolor="black"
)

axes[1].set_xticks(x)
axes[1].set_xticklabels(rep_labels)
axes[1].set_xlabel("Representation")
axes[1].set_ylabel("Macro F1")
axes[1].set_title("B. Random split overestimates performance")
axes[1].legend(frameon=False)

ymax_B = max(
    random_df["macro_f1"].max(),
    (donor_df["macro_f1"] + donor_df["macro_f1_std"]).max()
)
axes[1].set_ylim(0.72, ymax_B + 0.02)

for bars in [bars_random, bars_donor]:
    for bar in bars:
        h = bar.get_height()
        axes[1].text(
            bar.get_x() + bar.get_width()/2,
            h + 0.01,
            f"{h:.3f}",
            ha="center",
            va="bottom",
            fontsize=9
        )

# -------- Panel C --------
width = 0.36

bars_1 = axes[2].bar(
    x - width/2,
    fig2C_pivot[directions[0]],
    width,
    label=directions[0],
    edgecolor="black"
)

bars_2 = axes[2].bar(
    x + width/2,
    fig2C_pivot[directions[1]],
    width,
    label=directions[1],
    edgecolor="black"
)

axes[2].set_xticks(x)
axes[2].set_xticklabels(rep_labels)
axes[2].set_xlabel("Representation")
axes[2].set_ylabel("Macro F1")
axes[2].set_title("C. Cross-site generalization reveals directional performance asymmetry")

axes[2].legend(frameon=False)

ymin_C = fig2C_pivot.min().min()
ymax_C = fig2C_pivot.max().max()
axes[2].set_ylim(ymin_C - 0.02, ymax_C + 0.02)

for bars in [bars_1, bars_2]:
    for bar in bars:
        h = bar.get_height()
        axes[2].text(
            bar.get_x() + bar.get_width()/2,
            h + 0.005,
            f"{h:.3f}",
            ha="center",
            va="bottom",
            fontsize=9
        )

fig.suptitle(
    "Figure 2. Dataset construction, evaluation strategy, and site transfer affect apparent model performance",
    y=1.02
)

plt.tight_layout()

out_png = figures_dir / "figure2_three_panel.png"
plt.savefig(out_png, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved: {out_png}")
# Out:
# Scheme A columns: ['scheme', 'representation', 'macro_f1', 'accuracy', 'n_cells_used', 'n_classes_used', 'dataset', 'batch', 'batch_covariate', 'n_batch_features']
# Scheme B columns: ['scheme', 'dataset', 'batch', 'representation', 'macro_f1_mean', 'macro_f1_std', 'accuracy_mean', 'accuracy_std', 'n_folds', 'mean_train_cells', 'mean_test_cells', 'mean_n_classes_used', 'batch_covariate', 'mean_n_batch_features']
#              scheme representation  macro_f1  accuracy  n_cells_used  \
# 0            random            pca  0.789837  0.822948         10107
# 1            random            hvg  0.789520  0.817013         10107
# 2            random           scvi  0.757488  0.791790         10107
# 3            random        harmony  0.755549  0.789812         10107
# 4   random_batchcov            pca  0.794516  0.825420         10107
# 5   random_batchcov            hvg  0.790476  0.818497         10107
# 6   random_batchcov        harmony  0.765867  0.801682         10107
# 7   random_batchcov           scvi  0.765186  0.799209         10107
# 8            random            hvg  0.508945  0.766608         11289
# 9            random           scvi  0.508365  0.759522         11289
# 10           random        harmony  0.480396  0.753764         11289
# 11           random            pca  0.455523  0.772365         11289
# 12  random_batchcov           scvi  0.532800  0.766608         11289
# 13  random_batchcov            hvg  0.508551  0.766608         11289
# 14  random_batchcov            pca  0.472426  0.777236         11289
# 15  random_batchcov        harmony  0.460706  0.763950         11289
#
#     n_classes_used   dataset batch batch_covariate  n_batch_features
# 0               13  filtered    no             NaN               NaN
# 1               13  filtered    no             NaN               NaN
# 2               13  filtered    no             NaN               NaN
# 3               13  filtered    no             NaN               NaN
# 4               13  filtered   yes            Site               2.0
# 5               13  filtered   yes            Site               2.0
# 6               13  filtered   yes            Site               2.0
# 7               13  filtered   yes            Site               2.0
# 8               40      full    no             NaN               NaN
# 9               40      full    no             NaN               NaN
# 10              40      full    no             NaN               NaN
# 11              40      full    no             NaN               NaN
# 12              40      full   yes            Site               2.0
# 13              40      full   yes            Site               2.0
# 14              40      full   yes            Site               2.0
# 15              40      full   yes            Site               2.0
#                     scheme   dataset batch representation  macro_f1_mean  \
# 0           donor_held_out  filtered    no          X_pca       0.775636
# 1           donor_held_out  filtered    no            hvg       0.765229
# 2           donor_held_out  filtered    no      X_harmony       0.748225
# 3           donor_held_out  filtered    no         X_scVI       0.744218
# 4  donor_held_out_batchcov  filtered   yes          X_pca       0.776870
# 5  donor_held_out_batchcov  filtered   yes            hvg       0.764340
# 6  donor_held_out_batchcov  filtered   yes      X_harmony       0.747530
# 7  donor_held_out_batchcov  filtered   yes         X_scVI       0.743975
#
#    macro_f1_std  accuracy_mean  accuracy_std  n_folds  mean_train_cells  \
# 0      0.031406       0.813954      0.037290        5            8085.6
# 1      0.019433       0.802494      0.023497        5            8085.6
# 2      0.030225       0.788531      0.035855        5            8085.6
# 3      0.034787       0.787228      0.040640        5            8085.6
# 4      0.033406       0.814029      0.037734        5            8085.6
# 5      0.020338       0.801585      0.024353        5            8085.6
# 6      0.042606       0.791621      0.041989        5            8085.6
# 7      0.038099       0.790279      0.038479        5            8085.6
#
#    mean_test_cells  mean_n_classes_used batch_covariate  mean_n_batch_features
# 0           2021.4                 13.0             NaN                    0.0
# 1           2021.4                 13.0             NaN                    0.0
# 2           2021.4                 13.0             NaN                    0.0
# 3           2021.4                 13.0             NaN                    0.0
# 4           2021.4                 13.0            Site                    2.0
# 5           2021.4                 13.0            Site                    2.0
# 6           2021.4                 13.0            Site                    2.0
# 7           2021.4                 13.0            Site                    2.0
# Figure 2B plotting dataframe:
#   representation  macro_f1  accuracy  macro_f1_std    scheme_label
# 0            hvg  0.765229  0.802494      0.019433  Donor-held-out
# 1            hvg  0.789520  0.817013      0.000000    Random split
# 2            pca  0.775636  0.813954      0.031406  Donor-held-out
# 3            pca  0.789837  0.822948      0.000000    Random split
# 4        harmony  0.748225  0.788531      0.030225  Donor-held-out
# 5        harmony  0.755549  0.789812      0.000000    Random split
# 6           scvi  0.744218  0.787228      0.034787  Donor-held-out
# 7           scvi  0.757488  0.791790      0.000000    Random split
# Saved: results/figures/figure2_three_panel.png

# %%
# figure 3: batch covariate comparison in Scheme B

# -------------------------
# keep filtered dataset only
# -------------------------
fig3_df = schemeB[schemeB["dataset"] == "filtered"].copy()

# harmonize representation names
fig3_df["representation_clean"] = fig3_df["representation"].replace({
    "hvg": "hvg",
    "X_pca": "pca",
    "X_harmony": "harmony",
    "X_scVI": "scvi",
})

rep_order = ["hvg", "pca", "harmony", "scvi"]
rep_labels = ["HVG", "PCA", "Harmony", "scVI"]

# split into no-batch and batch panels
panel_A = (
    fig3_df[fig3_df["batch"] == "no"]
    .set_index("representation_clean")
    .reindex(rep_order)
)

panel_B = (
    fig3_df[fig3_df["batch"] == "yes"]
    .set_index("representation_clean")
    .reindex(rep_order)
)

print("Panel A:")
display(panel_A)

print("Panel B:")
display(panel_B)

# -------------------------
# plot
# -------------------------
x = np.arange(len(rep_order))
width = 0.65

fig, axes = plt.subplots(1, 2, figsize=(12, 5.5), sharey=True)

# common y-limits
ymin = min(
    (panel_A["macro_f1_mean"] - panel_A["macro_f1_std"]).min(),
    (panel_B["macro_f1_mean"] - panel_B["macro_f1_std"]).min(),
)
ymax = max(
    (panel_A["macro_f1_mean"] + panel_A["macro_f1_std"]).max(),
    (panel_B["macro_f1_mean"] + panel_B["macro_f1_std"]).max(),
)

# -------- Panel A --------
bars_A = axes[0].bar(
    x,
    panel_A["macro_f1_mean"],
    width,
    yerr=panel_A["macro_f1_std"],
    capsize=5,
    edgecolor="black"
)
axes[0].set_xticks(x)
axes[0].set_xticklabels(rep_labels)
axes[0].set_xlabel("Representation")
axes[0].set_ylabel("Macro F1")
axes[0].set_title("A. No batch covariate")

for bar in bars_A:
    h = bar.get_height()
    axes[0].text(
        bar.get_x() + bar.get_width() / 2,
        h + 0.003,
        f"{h:.3f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

# -------- Panel B --------
bars_B = axes[1].bar(
    x,
    panel_B["macro_f1_mean"],
    width,
    yerr=panel_B["macro_f1_std"],
    capsize=5,
    edgecolor="black"
)
axes[1].set_xticks(x)
axes[1].set_xticklabels(rep_labels)
axes[1].set_xlabel("Representation")
axes[1].set_title("B. With site covariate")

for bar in bars_B:
    h = bar.get_height()
    axes[1].text(
        bar.get_x() + bar.get_width() / 2,
        h + 0.003,
        f"{h:.3f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

for ax in axes:
    ax.set_ylim(ymin - 0.01, ymax + 0.015)

fig.suptitle("Figure 3. Effect of batch covariate on donor-held-out performance", y=1.02)
plt.tight_layout()

out_png = figures_dir / "figure3_schemeB_batch_comparison.png"
plt.savefig(out_png, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved: {out_png}")
# Out:
# Panel A:
#                               scheme   dataset batch representation  \
# representation_clean
# hvg                   donor_held_out  filtered    no            hvg
# pca                   donor_held_out  filtered    no          X_pca
# harmony               donor_held_out  filtered    no      X_harmony
# scvi                  donor_held_out  filtered    no         X_scVI
#
#                       macro_f1_mean  macro_f1_std  accuracy_mean  \
# representation_clean
# hvg                        0.765229      0.019433       0.802494
# pca                        0.775636      0.031406       0.813954
# harmony                    0.748225      0.030225       0.788531
# scvi                       0.744218      0.034787       0.787228
#
#                       accuracy_std  n_folds  mean_train_cells  \
# representation_clean
# hvg                       0.023497        5            8085.6
# pca                       0.037290        5            8085.6
# harmony                   0.035855        5            8085.6
# scvi                      0.040640        5            8085.6
#
#                       mean_test_cells  mean_n_classes_used batch_covariate  \
# representation_clean
# hvg                            2021.4                 13.0             NaN
# pca                            2021.4                 13.0             NaN
# harmony                        2021.4                 13.0             NaN
# scvi                           2021.4                 13.0             NaN
#
#                       mean_n_batch_features
# representation_clean
# hvg                                     0.0
# pca                                     0.0
# harmony                                 0.0
# scvi                                    0.0
# Panel B:
#                                        scheme   dataset batch representation  \
# representation_clean
# hvg                   donor_held_out_batchcov  filtered   yes            hvg
# pca                   donor_held_out_batchcov  filtered   yes          X_pca
# harmony               donor_held_out_batchcov  filtered   yes      X_harmony
# scvi                  donor_held_out_batchcov  filtered   yes         X_scVI
#
#                       macro_f1_mean  macro_f1_std  accuracy_mean  \
# representation_clean
# hvg                        0.764340      0.020338       0.801585
# pca                        0.776870      0.033406       0.814029
# harmony                    0.747530      0.042606       0.791621
# scvi                       0.743975      0.038099       0.790279
#
#                       accuracy_std  n_folds  mean_train_cells  \
# representation_clean
# hvg                       0.024353        5            8085.6
# pca                       0.037734        5            8085.6
# harmony                   0.041989        5            8085.6
# scvi                      0.038479        5            8085.6
#
#                       mean_test_cells  mean_n_classes_used batch_covariate  \
# representation_clean
# hvg                            2021.4                 13.0            Site
# pca                            2021.4                 13.0            Site
# harmony                        2021.4                 13.0            Site
# scvi                           2021.4                 13.0            Site
#
#                       mean_n_batch_features
# representation_clean
# hvg                                     2.0
# pca                                     2.0
# harmony                                 2.0
# scvi                                    2.0
# Saved: results/figures/figure3_schemeB_batch_comparison.png

# %%
# figure 4: per-class F1 heatmap for Scheme B (filtered, no batch)

# -------------------------
# paths
# -------------------------
schemeB_case1_dir = Path("results/schemeB_case1")
figures_dir = Path("results/figures")
figures_dir.mkdir(parents=True, exist_ok=True)

# file names from notebook outputs
rep_file_map = {
    "HVG": "schemeB_case1_hvg_mean_per_class_f1.csv",
    "PCA": "schemeB_case1_X_pca_mean_per_class_f1.csv",
    "Harmony": "schemeB_case1_X_harmony_mean_per_class_f1.csv",
    "scVI": "schemeB_case1_X_scVI_mean_per_class_f1.csv",
}

# -------------------------
# read and merge
# -------------------------
heatmap_parts = []

for rep_label, fname in rep_file_map.items():
    df = pd.read_csv(schemeB_case1_dir / fname)
    df = df[["cell_type", "f1"]].copy()
    df = df.rename(columns={"f1": rep_label})
    heatmap_parts.append(df)

heatmap_df = heatmap_parts[0]
for df in heatmap_parts[1:]:
    heatmap_df = heatmap_df.merge(df, on="cell_type", how="outer")

# sort cell types by mean F1 across representations
rep_cols = ["HVG", "PCA", "Harmony", "scVI"]
heatmap_df["mean_f1"] = heatmap_df[rep_cols].mean(axis=1)
heatmap_df = heatmap_df.sort_values("mean_f1", ascending=False).reset_index(drop=True)

# use cell_type as index for plotting
heatmap_plot = heatmap_df.set_index("cell_type")[rep_cols]

print("Figure 4 heatmap table:")
display(heatmap_df)

# -------------------------
# plot heatmap
# -------------------------
fig_height = max(6, 0.45 * heatmap_plot.shape[0])
fig, ax = plt.subplots(figsize=(7.5, fig_height))

im = ax.imshow(
    heatmap_plot.values,
    aspect="auto",
    vmin=0,
    vmax=1,
)

# axes
ax.set_xticks(np.arange(len(rep_cols)))
ax.set_xticklabels(rep_cols)
ax.set_yticks(np.arange(len(heatmap_plot.index)))
ax.set_yticklabels(heatmap_plot.index)

ax.set_xlabel("Representation")
ax.set_ylabel("Cell Type")
ax.set_title("Figure 4. Per-class F1 under donor-held-out evaluation")

# colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Mean per-class F1")

# optional in-cell text
for i in range(heatmap_plot.shape[0]):
    for j in range(heatmap_plot.shape[1]):
        val = heatmap_plot.iloc[i, j]
        ax.text(
            j,
            i,
            f"{val:.2f}",
            ha="center",
            va="center",
            fontsize=7,
            color="black"
        )

plt.tight_layout()

out_png = figures_dir / "figure4_schemeB_per_class_f1_heatmap.png"
plt.savefig(out_png, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved: {out_png}")
# Out:
# Figure 4 heatmap table:
#                                             cell_type       HVG       PCA  \
# 0                                        naive B cell  0.995878  1.000000
# 1                              CD14-positive monocyte  0.993192  0.992658
# 2   CD16-positive, CD56-dim natural killer cell, h...  0.953467  0.951901
# 3   CD16-negative, CD56-bright natural killer cell...  0.897794  0.859457
# 4                                    mature NK T cell  0.870048  0.868419
# 5   naive thymus-derived CD4-positive, alpha-beta ...  0.810045  0.846472
# 6            effector CD8-positive, alpha-beta T cell  0.789202  0.809478
# 7   naive thymus-derived CD8-positive, alpha-beta ...  0.771441  0.680202
# 8     effector memory CD8-positive, alpha-beta T cell  0.676920  0.717628
# 9      central memory CD4-positive, alpha-beta T cell  0.625485  0.658088
# 10                           mucosal invariant T cell  0.562268  0.669182
# 11                                   T-helper 22 cell  0.569464  0.622355
# 12                                 gamma-delta T cell  0.432773  0.407421
#
#      Harmony      scVI   mean_f1
# 0   1.000000  1.000000  0.998969
# 1   0.990366  0.991450  0.991917
# 2   0.929354  0.942747  0.944367
# 3   0.853364  0.866178  0.869198
# 4   0.867072  0.858740  0.866070
# 5   0.820351  0.811713  0.822145
# 6   0.744862  0.763876  0.776854
# 7   0.661297  0.675022  0.696991
# 8   0.685100  0.655708  0.683839
# 9   0.609165  0.624611  0.629337
# 10  0.653284  0.610186  0.623730
# 11  0.604122  0.573030  0.592243
# 12  0.308587  0.301574  0.362589
# Saved: results/figures/figure4_schemeB_per_class_f1_heatmap.png

# %%
# figure 5: confusion matrix (Scheme B, PCA, filtered dataset)

# -------------------------
# path
# -------------------------
cm_path = Path("results/schemeB_case1/schemeB_case1_X_pca_confusion_matrix_sum.csv")
figures_dir = Path("results/figures")
figures_dir.mkdir(parents=True, exist_ok=True)

# -------------------------
# load matrix
# -------------------------
cm_df = pd.read_csv(cm_path, index_col=0)

# normalize rows
cm = cm_df.values
row_sums = cm.sum(axis=1, keepdims=True)
cm_norm = np.divide(cm, row_sums, where=row_sums != 0)

# -------------------------
# plot
# -------------------------
fig, ax = plt.subplots(figsize=(10, 9))

im = ax.imshow(cm_norm, cmap="viridis", norm=PowerNorm(gamma=0.5))

# ticks
labels = cm_df.index.tolist()
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))

ax.set_xticklabels(labels, rotation=90)
ax.set_yticklabels(labels)

ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_title("Figure 5. Confusion matrix (donor-held-out, PCA)")

# colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Row-normalized proportion")

plt.tight_layout()

out_png = figures_dir / "figure5_confusion_matrix_pca.png"
plt.savefig(out_png, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved: {out_png}")
# Out:
# Saved: results/figures/figure5_confusion_matrix_pca.png

# %%
# figure 6: donor ablation curve

# -------------------------
# path
# -------------------------
ablation_path = Path("results/tables/donor_ablation_summary.csv")
figures_dir = Path("results/figures")
figures_dir.mkdir(parents=True, exist_ok=True)

# -------------------------
# read csv
# -------------------------
ablation_df = pd.read_csv(ablation_path)

print("Ablation columns:", ablation_df.columns.tolist())
display(ablation_df)

# harmonize representation names if needed
ablation_df["representation_clean"] = ablation_df["representation"].replace({
    "hvg": "HVG",
    "pca": "PCA",
    "harmony": "Harmony",
    "scvi": "scVI",
    "X_pca": "PCA",
    "X_harmony": "Harmony",
    "X_scVI": "scVI",
})

rep_order = ["HVG", "PCA", "Harmony", "scVI"]

# -------------------------
# plot
# -------------------------
fig, ax = plt.subplots(figsize=(8.5, 5.5))

for rep in rep_order:
    sub = (
        ablation_df[ablation_df["representation_clean"] == rep]
        .sort_values("k_train_donors")
        .copy()
    )

    ax.plot(
        sub["k_train_donors"],
        sub["macro_f1_mean"],
        marker="o",
        linewidth=2,
        label=rep
    )

    ax.errorbar(
        sub["k_train_donors"],
        sub["macro_f1_mean"],
        yerr=sub["macro_f1_std"],
        fmt="none",
        capsize=4
    )

ax.set_xlabel("Number of training donors")
ax.set_ylabel("Macro F1")
ax.set_title("Figure 6. Donor ablation under donor-held-out evaluation")
ax.legend(frameon=False, title="Representation")

ax.set_xticks(sorted(ablation_df["k_train_donors"].unique()))
ax.set_ylim(
    ablation_df["macro_f1_mean"].min() - 0.03,
    (ablation_df["macro_f1_mean"] + ablation_df["macro_f1_std"]).max() + 0.03
)

plt.tight_layout()

out_png = figures_dir / "figure6_donor_ablation.png"
plt.savefig(out_png, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved: {out_png}")
# Out:
# Ablation columns: ['representation', 'k_train_donors', 'macro_f1_mean', 'macro_f1_std', 'accuracy_mean', 'accuracy_std', 'mean_train_cells', 'mean_test_cells', 'mean_n_classes_used']
#    representation  k_train_donors  macro_f1_mean  macro_f1_std  accuracy_mean  \
# 0         harmony               3       0.672019      0.045301       0.712732
# 1         harmony               5       0.714775      0.015743       0.758139
# 2         harmony               8       0.736220      0.009037       0.772962
# 3         harmony              10       0.743356      0.008474       0.791493
# 4         harmony              15       0.757405      0.016730       0.796937
# 5         harmony              20       0.726524      0.015108       0.770169
# 6             hvg               3       0.653710      0.068984       0.696490
# 7             hvg               5       0.712121      0.023163       0.756918
# 8             hvg               8       0.749423      0.011331       0.785494
# 9             hvg              10       0.757629      0.010610       0.804111
# 10            hvg              15       0.768595      0.010243       0.804693
# 11            hvg              20       0.748181      0.020542       0.790960
# 12            pca               3       0.720244      0.038632       0.760344
# 13            pca               5       0.747050      0.012845       0.788759
# 14            pca               8       0.777050      0.008150       0.810562
# 15            pca              10       0.768615      0.015385       0.815777
# 16            pca              15       0.785813      0.007626       0.824076
# 17            pca              20       0.760604      0.020769       0.803302
# 18           scvi               3       0.668471      0.062649       0.708286
# 19           scvi               5       0.713472      0.034010       0.755324
# 20           scvi               8       0.739556      0.017362       0.776570
# 21           scvi              10       0.735864      0.005775       0.785927
# 22           scvi              15       0.753638      0.019333       0.793407
# 23           scvi              20       0.728525      0.023175       0.775687
#
#     accuracy_std  mean_train_cells  mean_test_cells  mean_n_classes_used
# 0       0.043351            1297.2           8809.8                 13.0
# 1       0.018409            2161.0           7946.0                 13.0
# 2       0.018187            3509.6           6597.4                 13.0
# 3       0.009600            4401.6           5705.4                 13.0
# 4       0.016833            6581.6           3525.4                 13.0
# 5       0.039392            8777.8           1329.2                 13.0
# 6       0.061090            1297.2           8809.8                 13.0
# 7       0.022867            2161.0           7946.0                 13.0
# 8       0.022850            3509.6           6597.4                 13.0
# 9       0.012599            4401.6           5705.4                 13.0
# 10      0.015809            6581.6           3525.4                 13.0
# 11      0.044251            8777.8           1329.2                 13.0
# 12      0.036383            1297.2           8809.8                 13.0
# 13      0.014917            2161.0           7946.0                 13.0
# 14      0.016863            3509.6           6597.4                 13.0
# 15      0.013183            4401.6           5705.4                 13.0
# 16      0.015046            6581.6           3525.4                 13.0
# 17      0.049445            8777.8           1329.2                 13.0
# 18      0.057278            1297.2           8809.8                 13.0
# 19      0.039896            2161.0           7946.0                 13.0
# 20      0.030469            3509.6           6597.4                 13.0
# 21      0.009143            4401.6           5705.4                 13.0
# 22      0.020051            6581.6           3525.4                 13.0
# 23      0.045590            8777.8           1329.2                 13.0
# Saved: results/figures/figure6_donor_ablation.png

# %%
# =========================================================
# Supplementary Figure: T-cell subtype donor ablation curve
# =========================================================

tcell_ablation_path = Path("results/tables/tcell_donor_ablation_summary.csv")
figures_dir = Path("results/figures")
figures_dir.mkdir(parents=True, exist_ok=True)

tcell_ablation_df = pd.read_csv(tcell_ablation_path)

tcell_ablation_df["representation_clean"] = tcell_ablation_df["representation"].replace({
    "hvg": "HVG",
    "pca": "PCA",
    "harmony": "Harmony",
    "scvi": "scVI",
    "X_pca": "PCA",
    "X_harmony": "Harmony",
    "X_scVI": "scVI",
})

rep_order = ["HVG", "PCA", "Harmony", "scVI"]

fig, ax = plt.subplots(figsize=(8.5, 5.5))

for rep in rep_order:
    sub = (
        tcell_ablation_df[tcell_ablation_df["representation_clean"] == rep]
        .sort_values("k_train_donors")
        .copy()
    )

    ax.plot(
        sub["k_train_donors"],
        sub["macro_f1_mean"],
        marker="o",
        linewidth=2,
        label=rep
    )

    ax.errorbar(
        sub["k_train_donors"],
        sub["macro_f1_mean"],
        yerr=sub["macro_f1_std"],
        fmt="none",
        capsize=4
    )

ax.set_xlabel("Number of training donors")
ax.set_ylabel("Macro F1")
ax.set_title("Supplementary Figure S4. T-cell subtype donor ablation")
ax.legend(frameon=False, title="Representation")

ax.set_xticks(sorted(tcell_ablation_df["k_train_donors"].unique()))
ax.set_ylim(
    tcell_ablation_df["macro_f1_mean"].min() - 0.03,
    (tcell_ablation_df["macro_f1_mean"] + tcell_ablation_df["macro_f1_std"]).max() + 0.03
)

plt.tight_layout()

out_png = figures_dir / "supplementary_S4_tcell_donor_ablation.png"
plt.savefig(out_png, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved: {out_png}")
# Out:
# Saved: results/figures/supplementary_S4_tcell_donor_ablation.png

# %% [markdown]
# **Additional Figures**

# %%
# =========================
# SUPPLEMENTARY FIGURE S1
# Scheme A: Random split
# Effect of batch covariate
# =========================

figS1_df = schemeA.copy()

# restrict to filtered dataset
figS1_df = figS1_df[figS1_df["dataset"] == "filtered"].copy()

# clean representation names
figS1_df["representation_clean"] = figS1_df["representation"].replace({
    "hvg": "hvg",
    "X_pca": "pca",
    "X_harmony": "harmony",
    "X_scVI": "scvi",
})

rep_order = ["hvg", "pca", "harmony", "scvi"]
rep_labels = ["HVG", "PCA", "Harmony", "scVI"]

# split panels
panel_A = (
    figS1_df[figS1_df["batch"] == "no"]
    .set_index("representation_clean")
    .reindex(rep_order)
)

panel_B = (
    figS1_df[figS1_df["batch"] == "yes"]
    .set_index("representation_clean")
    .reindex(rep_order)
)

# -------------------------
# plot
# -------------------------
x = np.arange(len(rep_order))
width = 0.65

fig, axes = plt.subplots(1, 2, figsize=(12, 5.5), sharey=True)

# -------- Panel A --------
bars_A = axes[0].bar(
    x,
    panel_A["macro_f1"],
    width,
    edgecolor="black"
)

axes[0].set_xticks(x)
axes[0].set_xticklabels(rep_labels)
axes[0].set_xlabel("Representation")
axes[0].set_ylabel("Macro F1")
axes[0].set_title("A. No batch covariate")

# labels
for bar in bars_A:
    h = bar.get_height()
    axes[0].text(
        bar.get_x() + bar.get_width() / 2,
        h + 0.003,
        f"{h:.3f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

# -------- Panel B --------
bars_B = axes[1].bar(
    x,
    panel_B["macro_f1"],
    width,
    edgecolor="black"
)

axes[1].set_xticks(x)
axes[1].set_xticklabels(rep_labels)
axes[1].set_xlabel("Representation")
axes[1].set_title("B. With site covariate")

for bar in bars_B:
    h = bar.get_height()
    axes[1].text(
        bar.get_x() + bar.get_width() / 2,
        h + 0.003,
        f"{h:.3f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

# shared y-axis
ymin = min(panel_A["macro_f1"].min(), panel_B["macro_f1"].min())
ymax = max(panel_A["macro_f1"].max(), panel_B["macro_f1"].max())

for ax in axes:
    ax.set_ylim(ymin - 0.01, ymax + 0.015)

fig.suptitle(
    "Supplementary Figure S1. Effect of batch covariate under random split (Scheme A)",
    y=1.02
)

plt.tight_layout()

out_png = figures_dir / "supplementary_S1_schemeA_batch.png"
plt.savefig(out_png, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved: {out_png}")
# Out:
# Saved: results/figures/supplementary_S1_schemeA_batch.png
