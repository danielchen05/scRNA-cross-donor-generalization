# %%
import sys
from pathlib import Path

REPO_ROOT = Path("~/scRNA-cross-donor-generalization").expanduser()
sys.path.append(str(REPO_ROOT / "src"))

from scrna_benchmark.representations import get_representation
from scrna_benchmark.models import run_random_split_logreg, run_donor_split_logreg
from scrna_benchmark.splits import make_donor_folds
from scrna_benchmark.experiments import run_random_split_experiment, run_donor_cv_experiment
